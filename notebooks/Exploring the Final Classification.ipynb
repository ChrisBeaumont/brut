# %%
# %pylab

import json

from bubbly.extractors import RGBExtractor
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.kernel.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.
# /Users/beaumont/Library/Python/2.7/lib/python/site-packages/scikits/__init__.py:1: UserWarning: Module argparse was already imported from /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/argparse.pyc, but /Users/beaumont/Library/Python/2.7/lib/python/site-packages is being added to sys.path
#   __import__('pkg_resources').declare_namespace(__name__)

# %%
data = json.load(open('../models/benchmark_scores.json'))

ind = np.argsort(data['off_score'])[::-1]

# %%
ex = RGBExtractor()
ex.shp = (200, 200)

# %%
def _ex(param):
    r1 = ex.extract(*param)
    p2 = list(param)
    p2[-1] *= 2
    r2 = ex.extract(*p2)
    return np.hstack((r1, r2))

hard_off = [_ex(data['off'][i]) for i in ind[:100]]
collage = np.vstack(np.hstack(hard_off[i:i+10]) for i in range(0, len(hard_off), 10))


figure(figsize=(12, 12), dpi=200) 
imshow(collage, origin='upper')
# Out:
# Loading a new field at l=324
# Loading a new field at l=53
# Loading a new field at l=298
# Loading a new field at l=14
# Loading a new field at l=60
# Loading a new field at l=313
# Loading a new field at l=314
# Loading a new field at l=40
# Loading a new field at l=31
# Loading a new field at l=303
# Loading a new field at l=50
# Loading a new field at l=27
# Loading a new field at l=56
# Loading a new field at l=332
# Loading a new field at l=22
# Loading a new field at l=326
# Loading a new field at l=38
# Loading a new field at l=33
# Loading a new field at l=60
# Loading a new field at l=30
# Loading a new field at l=332
# Loading a new field at l=22
# Loading a new field at l=65
# Loading a new field at l=42
# Loading a new field at l=11
# Loading a new field at l=24
# Loading a new field at l=51
# Loading a new field at l=309
# Loading a new field at l=320
# Loading a new field at l=61
# Loading a new field at l=317
# Loading a new field at l=56
# Loading a new field at l=53
# Loading a new field at l=349
# Loading a new field at l=49
# Loading a new field at l=308
# Loading a new field at l=344
# Loading a new field at l=338
# Loading a new field at l=41
# Loading a new field at l=60
# Loading a new field at l=35
# Loading a new field at l=303
# Loading a new field at l=26
# Loading a new field at l=330
# Loading a new field at l=328
# Loading a new field at l=298
# Loading a new field at l=50
# Loading a new field at l=25
# Loading a new field at l=348
# Loading a new field at l=329
# Loading a new field at l=53
# Loading a new field at l=308
# Loading a new field at l=332
# Loading a new field at l=65
# Loading a new field at l=302
# Loading a new field at l=311
# Loading a new field at l=43
# Loading a new field at l=304
# Loading a new field at l=321
# Loading a new field at l=301
# Loading a new field at l=36
# Loading a new field at l=318
# Loading a new field at l=35
# Loading a new field at l=44
# Loading a new field at l=309
# Loading a new field at l=40
# Loading a new field at l=323
# Loading a new field at l=302
# Loading a new field at l=32
# Loading a new field at l=323
# Loading a new field at l=26
# Loading a new field at l=317
# Loading a new field at l=16
# Loading a new field at l=332
# Loading a new field at l=338
# Loading a new field at l=56
# Loading a new field at l=43
# Loading a new field at l=342
# Loading a new field at l=13
# Loading a new field at l=49
# Loading a new field at l=321
# Loading a new field at l=56
# Loading a new field at l=29
# Loading a new field at l=11
# Loading a new field at l=329
# Loading a new field at l=44
# Loading a new field at l=348
# Loading a new field at l=54
# Loading a new field at l=319
# Loading a new field at l=32
# Loading a new field at l=51
# Loading a new field at l=41
# Loading a new field at l=296
# Loading a new field at l=44
# Loading a new field at l=24
# Loading a new field at l=18
# Loading a new field at l=14
# Loading a new field at l=51
# Loading a new field at l=325
# Loading a new field at l=13

# %%
hist(data['off_score'], histtype='step', color='r', label='Negative')
hist(data['on_score'], histtype='step', color='g', label='Positive')
legend()
yscale('log')
